# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3 sns.set(style="whitegrid")
#
# File /opt/conda/lib/python3.11/site-packages/seaborn/__init__.py:2
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File /opt/conda/lib/python3.11/site-packages/seaborn/rcmod.py:5
#       3 import matplotlib as mpl
#       4 from cycler import cycler
# ----> 5 from . import palettes
#       8 __all__ = ["set_theme", "set", "reset_defaults", "reset_orig",
#       9            "axes_style", "set_style", "plotting_context", "set_context",
#      10            "set_palette"]
#      13 _style_keys = [
#      14
#      15     "axes.facecolor",
#    (...)
#      50
#      51 ]
#
# File /opt/conda/lib/python3.11/site-packages/seaborn/palettes.py:9
#       5 import matplotlib as mpl
#       7 from .external import husl
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11 from ._compat import get_colormap
#
# File /opt/conda/lib/python3.11/site-packages/seaborn/utils.py:11
#       8 from types import ModuleType
#      10 import numpy as np
# ---> 11 import pandas as pd
#      12 import matplotlib as mpl
#      13 from matplotlib.colors import to_rgb
#
# File /opt/conda/lib/python3.11/site-packages/pandas/__init__.py:49
#      46 # let init-time option registration happen
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 49 from pandas.core.api import (
#      50     # dtype
#      51     ArrowDtype,
#      52     Int8Dtype,
#      53     Int16Dtype,
#      54     Int32Dtype,
#      55     Int64Dtype,
#      56     UInt8Dtype,
#      57     UInt16Dtype,
#      58     UInt32Dtype,
#      59     UInt64Dtype,
#      60     Float32Dtype,
#      61     Float64Dtype,
#      62     CategoricalDtype,
#      63     PeriodDtype,
#      64     IntervalDtype,
#      65     DatetimeTZDtype,
#      66     StringDtype,
#      67     BooleanDtype,
#      68     # missing
#      69     NA,
#      70     isna,
#      71     isnull,
#      72     notna,
#      73     notnull,
#      74     # indexes
#      75     Index,
#      76     CategoricalIndex,
#      77     RangeIndex,
#      78     MultiIndex,
#      79     IntervalIndex,
#      80     TimedeltaIndex,
#      81     DatetimeIndex,
#      82     PeriodIndex,
#      83     IndexSlice,
#      84     # tseries
#      85     NaT,
#      86     Period,
#      87     period_range,
#      88     Timedelta,
#      89     timedelta_range,
#      90     Timestamp,
#      91     date_range,
#      92     bdate_range,
#      93     Interval,
#      94     interval_range,
#      95     DateOffset,
#      96     # conversion
#      97     to_numeric,
#      98     to_datetime,
#      99     to_timedelta,
#     100     # misc
#     101     Flags,
#     102     Grouper,
#     103     factorize,
#     104     unique,
#     105     value_counts,
#     106     NamedAgg,
#     107     array,
#     108     Categorical,
#     109     set_eng_float_format,
#     110     Series,
#     111     DataFrame,
#     112 )
#     114 from pandas.core.dtypes.dtypes import SparseDtype
#     116 from pandas.tseries.api import infer_freq
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)
#      14     PeriodDtype,
#      15 )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/_libs/__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)
#      26     iNaT,
#      27 )
#
# File pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# File pandas/_libs/hashtable.pyx:1, in init pandas._libs.hashtable()
#
# File pandas/_libs/missing.pyx:1, in init pandas._libs.missing()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/_libs/tslibs/__init__.py:40
#       1 __all__ = [
#       2     "dtypes",
#       3     "localize_pydatetime",
#    (...)
#      36     "is_supported_dtype",
#      37 ]
#      39 from pandas._libs.tslibs import dtypes  # pylint: disable=import-self
# ---> 40 from pandas._libs.tslibs.conversion import localize_pydatetime
#      41 from pandas._libs.tslibs.dtypes import (
#      42     Resolution,
#      43     periods_per_day,
#      44     periods_per_second,
#      45 )
#      46 from pandas._libs.tslibs.nattype import (
#      47     NaT,
#      48     NaTType,
#      49     iNaT,
#      50     nat_strings,
#      51 )
#
# File pandas/_libs/tslibs/conversion.pyx:1, in init pandas._libs.tslibs.conversion()
#
# File pandas/_libs/tslibs/offsets.pyx:1, in init pandas._libs.tslibs.offsets()
#
# File pandas/_libs/tslibs/timestamps.pyx:1, in init pandas._libs.tslibs.timestamps()
#
# File pandas/_libs/tslibs/timedeltas.pyx:1, in init pandas._libs.tslibs.timedeltas()
#
# File pandas/_libs/tslibs/timezones.pyx:49, in init pandas._libs.tslibs.timezones()
#
# File /opt/conda/lib/python3.11/site-packages/dateutil/tz/tz.py:1557, in __get_gettz.<locals>.GettzFunc.__call__(self, name)
#    1554 rv = self.__instances.get(name, None)
#    1556 if rv is None:
# -> 1557     rv = self.nocache(name=name)
#    1558     if not (name is None
#    1559             or isinstance(rv, tzlocal_classes)
#    1560             or rv is None):
#    (...)
#    1565         # We also cannot store weak references to None, so we
#    1566         # will also not store that.
#    1567         self.__instances[name] = rv
#
# File /opt/conda/lib/python3.11/site-packages/dateutil/tz/tz.py:1655, in __get_gettz.<locals>.GettzFunc.nocache(name)
#    1653 if not tz:
#    1654     from dateutil.zoneinfo import get_zonefile_instance
# -> 1655     tz = get_zonefile_instance().get(name)
#    1657 if not tz:
#    1658     for c in name:
#    1659         # name is not a tzstr unless it has at least
#    1660         # one offset. For short values of "name", an
#    1661         # explicit for loop seems to be the fastest way
#    1662         # To determine if a string contains a digit
#
# File /opt/conda/lib/python3.11/site-packages/dateutil/zoneinfo/__init__.py:102, in get_zonefile_instance(new_instance)
#      99     zif = getattr(get_zonefile_instance, '_cached_instance', None)
#     101 if zif is None:
# --> 102     zif = ZoneInfoFile(getzoneinfofile_stream())
#     104     get_zonefile_instance._cached_instance = zif
#     106 return zif
#
# File /opt/conda/lib/python3.11/site-packages/dateutil/zoneinfo/__init__.py:35, in ZoneInfoFile.__init__(self, zonefile_stream)
#      32 if zonefile_stream is not None:
#      33     with TarFile.open(fileobj=zonefile_stream) as tf:
#      34         self.zones = {zf.name: tzfile(tf.extractfile(zf), filename=zf.name)
# ---> 35                       for zf in tf.getmembers()
#      36                       if zf.isfile() and zf.name != METADATA_FN}
#      37         # deal with links: They'll point to their parent object. Less
#      38         # waste of memory
#      39         links = {zl.name: self.zones[zl.linkname]
#      40                  for zl in tf.getmembers() if
#      41                  zl.islnk() or zl.issym()}
#
# File /opt/conda/lib/python3.11/tarfile.py:1994, in TarFile.getmembers(self)
#    1992 self._check()
#    1993 if not self._loaded:    # if we want to obtain a list of
# -> 1994     self._load()        # all members, we first have to
#    1995                         # scan the whole archive.
#    1996 return self.members
#
# File /opt/conda/lib/python3.11/tarfile.py:2691, in TarFile._load(self)
#    2687 """Read through the entire archive file and look for readable
#    2688    members.
#    2689 """
#    2690 while True:
# -> 2691     tarinfo = self.next()
#    2692     if tarinfo is None:
#    2693         break
#
# File /opt/conda/lib/python3.11/tarfile.py:2604, in TarFile.next(self)
#    2602 while True:
#    2603     try:
# -> 2604         tarinfo = self.tarinfo.fromtarfile(self)
#    2605     except EOFHeaderError as e:
#    2606         if self.ignore_zeros:
#
# File /opt/conda/lib/python3.11/tarfile.py:1295, in TarInfo.fromtarfile(cls, tarfile)
#    1293 obj = cls.frombuf(buf, tarfile.encoding, tarfile.errors)
#    1294 obj.offset = tarfile.fileobj.tell() - BLOCKSIZE
# -> 1295 return obj._proc_member(tarfile)
#
# File /opt/conda/lib/python3.11/tarfile.py:1317, in TarInfo._proc_member(self, tarfile)
#    1315     return self._proc_sparse(tarfile)
#    1316 elif self.type in (XHDTYPE, XGLTYPE, SOLARIS_XHDTYPE):
# -> 1317     return self._proc_pax(tarfile)
#    1318 else:
#    1319     return self._proc_builtin(tarfile)
#
# File /opt/conda/lib/python3.11/tarfile.py:1469, in TarInfo._proc_pax(self, tarfile)
#    1467 # Fetch the next header.
#    1468 try:
# -> 1469     next = self.fromtarfile(tarfile)
#    1470 except HeaderError as e:
#    1471     raise SubsequentHeaderError(str(e)) from None
#
# File /opt/conda/lib/python3.11/tarfile.py:1293, in TarInfo.fromtarfile(cls, tarfile)
#    1289 """Return the next TarInfo object from TarFile object
#    1290    tarfile.
#    1291 """
#    1292 buf = tarfile.fileobj.read(BLOCKSIZE)
# -> 1293 obj = cls.frombuf(buf, tarfile.encoding, tarfile.errors)
#    1294 obj.offset = tarfile.fileobj.tell() - BLOCKSIZE
#    1295 return obj._proc_member(tarfile)
#
# File /opt/conda/lib/python3.11/tarfile.py:1244, in TarInfo.frombuf(cls, buf, encoding, errors)
#    1242 obj.uid = nti(buf[108:116])
#    1243 obj.gid = nti(buf[116:124])
# -> 1244 obj.size = nti(buf[124:136])
#    1245 obj.mtime = nti(buf[136:148])
#    1246 obj.chksum = chksum
#
# File /opt/conda/lib/python3.11/tarfile.py:190, in nti(s)
#     188 else:
#     189     try:
# --> 190         s = nts(s, "ascii", "strict")
#     191         n = int(s.strip() or "0", 8)
#     192     except ValueError:
#
# File /opt/conda/lib/python3.11/tarfile.py:168, in nts(s, encoding, errors)
#     165     s = s.encode(encoding, errors)
#     166     return s[:length] + (length - len(s)) * NUL
# --> 168 def nts(s, encoding, errors):
#     169     """Convert a null-terminated bytes object to a string.
#     170     """
#     171     p = s.find(b"\0")
#
# KeyboardInterrupt:

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.tail()

# %%
df.describe()

# %%
sns.histplot(df)

# %%
sns.barplot(df)

# %%
# Просмотр первых строк
df.head()
# Информация о структуре таблицы
df.info()
# Статистика по числовым признакам
df.describe()
# Количество пропущенных значений
df.isnull().sum()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Age'].dropna(), kde=True)
plt.title("Распределение возраста")
plt.show()
# Выживаемость по полу и классу:
plt.figure(figsize=(8, 5))
sns.barplot(x='Sex', y='Survived', data=df)
plt.title("Выживаемость по полу")
plt.show()

plt.figure(figsize=(8, 5))
sns.barplot(x='Pclass', y='Survived', data=df)
plt.title("Выживаемость по классу")
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Корреляционная матрица")
plt.show()
